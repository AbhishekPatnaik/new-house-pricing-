# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('/home/abhishek/Downloads/DATASETS/kc_house_data.csv')
data.head()
data['id'] = data['id'].astype('category').cat.codes
data
# Out:
#           id             date      price  bedrooms  bathrooms  sqft_living  \
# 0      15339  20141013T000000   221900.0         3       1.00         1180
# 1      14466  20141209T000000   538000.0         3       2.25         2570
# 2      13503  20150225T000000   180000.0         2       1.00          770
# 3       6371  20141209T000000   604000.0         4       3.00         1960
# 4       4955  20150218T000000   510000.0         3       2.00         1680
# 5      15933  20140512T000000  1225000.0         4       4.50         5420
# 6       2956  20140627T000000   257500.0         3       2.25         1715
# 7       5078  20150115T000000   291850.0         3       1.50         1060
# 8       6043  20150415T000000   229500.0         3       1.00         1780
# 9      10219  20150312T000000   323000.0         3       2.50         1890
# 10      4169  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
data1=data
data1 = data1.drop('date',axis=1)
for i in data1.columns:
    plt.scatter(data1['id'],data1[i])
    plt.title(i)
    plt.show()

# %%
#max(data['price'])
min(data['price'])
# Out:
# 75000.0

# %%
for i in data1.columns:
    sns.distplot(data1[i])
    sns.plt.show()

# %%
#-------------checking for null places--------------------
for i in data.columns:
    print(data[i].loc[data[i].isnull()==True])
    #---------so sweet of the data but remember if the data is alredy clean then "kuch to gadbad h"------------
# Out:
# Series([], Name: id, dtype: int16)
# Series([], Name: date, dtype: object)
# Series([], Name: price, dtype: float64)
# Series([], Name: bedrooms, dtype: int64)
# Series([], Name: bathrooms, dtype: float64)
# Series([], Name: sqft_living, dtype: int64)
# Series([], Name: sqft_lot, dtype: int64)
# Series([], Name: floors, dtype: float64)
# Series([], Name: waterfront, dtype: int64)
# Series([], Name: view, dtype: int64)
# Series([], Name: condition, dtype: int64)
# Series([], Name: grade, dtype: int64)
# Series([], Name: sqft_above, dtype: int64)
# Series([], Name: sqft_basement, dtype: int64)
# Series([], Name: yr_built, dtype: int64)
# Series([], Name: yr_renovated, dtype: int64)
# Series([], Name: zipcode, dtype: int64)
# Series([], Name: lat, dtype: float64)
# Series([], Name: long, dtype: float64)
# Series([], Name: sqft_living15, dtype: int64)
# Series([], Name: sqft_lot15, dtype: int64)

# %%
corr = data.corr()
cols = corr.nlargest(5,'price')['price'].index
cm=np.corrcoef(data[cols].values.T)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
y=data['price']
data = data.drop(['price','date'],axis=1)

from sklearn.cross_validation import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data,y,test_size=0.25,random_state=21)

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
# Out:
# 0.703427754762

# %%
from scipy.stats import skew
